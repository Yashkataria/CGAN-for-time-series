# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from scipy.interpolate import CubicSpline
from scipy import signal
import json
import os
import sklearn

# %%
tf.config.experimental.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # DATA PREPERATION

# %% [markdown]
# Interpolating cross-section data

# %%
#with open('D:\\BTP\\temp\\usable_data_generated', 'r') as fout:
#    usable_data_generated = json.load(fout)
    
with open('usable_data', 'r') as fout:
    usable_data = json.load(fout)
    
# usable_data += usable_data_generated

# %% [markdown]
# Preparing cross-section data by stacking elastic,ionization and excitation cross sections.
#
# Data is converted into log and then normalize between -1 and 1 using min max

# %%
import math

elastic_crosssection = []
ionization_crosssection = []
excitation_crosssection = []
elastic_energy = []
ionization_energy = []
excitation_energy = []

for species in usable_data:   
    elastic_crosssection.append(species['elastic']['crosssection'])
    ionization_crosssection.append(species['ionization']['crosssection'])
    excitation_crosssection.append(species['excitation']['crosssection'])
    elastic_energy.append(species['elastic']['energy'])
    ionization_energy.append(species['ionization']['energy'])
    excitation_energy.append(species['excitation']['energy'])

elastic_crosssection = np.array(elastic_crosssection)
ionization_crosssection = np.array(ionization_crosssection)
excitation_crosssection = np.array(excitation_crosssection)
crosssection_data = np.stack([elastic_crosssection,ionization_crosssection,excitation_crosssection], axis=2)
crosssection_data = np.swapaxes(crosssection_data,1,2)

crosssection_data = crosssection_data + 10**-25
crosssection_data = np.log(crosssection_data)

# Normalizing between -1 and 1 by min max

min_crosssection = np.amin(crosssection_data,axis=(0,2),keepdims=True)

max_crosssection = np.amax(crosssection_data,axis=(0,2),keepdims=True)

crosssection_data = 2*(crosssection_data - min_crosssection)/(max_crosssection - min_crosssection) - 1

# y = 2*(x-min)/(max-min) - 1
# x = (y+1)*(max-min)/2 + min

print("Shape of min_crosssection :",min_crosssection.shape)
print("Shape of max_crosssection :",max_crosssection.shape)
print("Shape of crosssection_data :",crosssection_data.shape)
# Out:
# Shape of min_crosssection : (1, 3, 1)
# Shape of max_crosssection : (1, 3, 1)
# Shape of crosssection_data : (46, 3, 100)

# %% [markdown]
# # WGAN2 FOR GENERATING SPECTOGRAMS

# %% [markdown]
# Loading generator1

# %%
generator1 = keras.models.load_model('/content/drive/MyDrive/generator_model1_1000epoch/')
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
noise_dim = 10
BATCH_SIZE = 10
train_images = crosssection_data[:,0,:]
train_images = train_images.reshape(crosssection_data.shape[0],crosssection_data.shape[2],1)
train_images = train_images.reshape(train_images.shape[0], *(100,1,1)).astype("float32")
np.random.shuffle(train_images)
D = 32
train_images.shape
# Out:
# (46, 100, 1, 1)

# %%
def make_discriminator2():
    input_img = layers.Input(shape=(100,1,1))
    
    x = layers.Reshape((100,1))(input_img)
    
    x = layers.Conv1D(D, 5, strides=2, padding='same')(x)
    x = layers.LeakyReLU(0.2)(x)
    
    x = layers.Conv1D(D*2, 5, strides=2, padding='same')(x)
    x = layers.LeakyReLU(0.2)(x)
    
    x = layers.Conv1D(D*4, 5, strides=2, padding='same')(x)
    x = layers.LeakyReLU(0.2)(x)
    
    x = layers.Conv1D(D*8, 5, strides=2, padding='same')(x)
    x = layers.LeakyReLU(0.2)(x)
    
    x = layers.Conv1D(D*16, 5, strides=2, padding='same')(x)
    x = layers.LeakyReLU(0.2)(x)
    
#     x = layers.Conv1D(D*32, 5, strides=2, padding='same')(x)
#     x = layers.LeakyReLU(0.2)(x)
    
    x = layers.Flatten()(x)
    x = layers.Dense(1)(x)
        
    discriminator2 = keras.models.Model(input_img, x, name="discriminator2")
    return discriminator2

discriminator2 = make_discriminator2()
discriminator2.summary()
# Out:
# Model: "discriminator2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 100, 1, 1)]       0
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 100, 1)            0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 50, 32)            192
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 50, 32)            0
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 25, 64)            10304
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 25, 64)            0
# _________________________________________________________________
# conv1d_17 (Conv1D)           (None, 13, 128)           41088
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 13, 128)           0
# _________________________________________________________________
# conv1d_18 (Conv1D)           (None, 7, 256)            164096
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 7, 256)            0
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, 4, 512)            655872
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 4, 512)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 2049
# =================================================================
# Total params: 873,601
# Trainable params: 873,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
D = 16

def make_generator2():
    noise = layers.Input(shape=(50,1,1))
    
    x = layers.Reshape((50,1))(noise)
    
    x = layers.Conv1D(16 * D, 10, strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    
    x = layers.Conv1D(8 * D, 10, strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
        
    x = layers.Conv1D(4 * D, 10, strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    
    x = layers.Conv1D(2 * D, 10, strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    
    x = layers.Conv1D(1 , 10, strides=1, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
        
    x = layers.UpSampling1D(size=2)(x)
    x = layers.Conv1D(2 * D, 10, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
        
    x = layers.UpSampling1D(size=2)(x)
    x = layers.Conv1D(4 * D, 10, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    
    x = layers.Cropping1D(1)(x)
    
    x = layers.UpSampling1D(size=2)(x)
    x = layers.Conv1D(4 * D, 10, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    
    x = layers.Cropping1D(1)(x)
    
    x = layers.UpSampling1D(size=2)(x)
    x = layers.Conv1D(8 * D, 10, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    
    x = layers.Cropping1D(1)(x)
    
    x = layers.UpSampling1D(size=2)(x)
    x = layers.Conv1D(1, 10, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("tanh")(x)
    
    x = layers.Reshape((100,1,1))(x)
    
    generator2 = keras.models.Model(noise, x, name="generator2")
    return generator2

generator2 = make_generator2()
generator2.summary()
# Out:
# Model: "generator2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 50, 1, 1)]        0
# _________________________________________________________________
# reshape_4 (Reshape)          (None, 50, 1)             0
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 25, 256)           2816
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 25, 256)           1024
# _________________________________________________________________
# activation_10 (Activation)   (None, 25, 256)           0
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 13, 128)           327808
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 13, 128)           512
# _________________________________________________________________
# activation_11 (Activation)   (None, 13, 128)           0
# _________________________________________________________________
# conv1d_22 (Conv1D)           (None, 7, 64)             81984
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 7, 64)             256
# _________________________________________________________________
# activation_12 (Activation)   (None, 7, 64)             0
# _________________________________________________________________
# conv1d_23 (Conv1D)           (None, 4, 32)             20512
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 4, 32)             128
# _________________________________________________________________
# activation_13 (Activation)   (None, 4, 32)             0
# _________________________________________________________________
# conv1d_24 (Conv1D)           (None, 4, 1)              321
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 4, 1)              4
# _________________________________________________________________
# activation_14 (Activation)   (None, 4, 1)              0
# _________________________________________________________________
# up_sampling1d_5 (UpSampling1 (None, 8, 1)              0
# _________________________________________________________________
# conv1d_25 (Conv1D)           (None, 8, 32)             352
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 8, 32)             128
# _________________________________________________________________
# activation_15 (Activation)   (None, 8, 32)             0
# _________________________________________________________________
# up_sampling1d_6 (UpSampling1 (None, 16, 32)            0
# _________________________________________________________________
# conv1d_26 (Conv1D)           (None, 16, 64)            20544
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 16, 64)            256
# _________________________________________________________________
# activation_16 (Activation)   (None, 16, 64)            0
# _________________________________________________________________
# cropping1d_3 (Cropping1D)    (None, 14, 64)            0
# _________________________________________________________________
# up_sampling1d_7 (UpSampling1 (None, 28, 64)            0
# _________________________________________________________________
# conv1d_27 (Conv1D)           (None, 28, 64)            41024
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 28, 64)            256
# _________________________________________________________________
# activation_17 (Activation)   (None, 28, 64)            0
# _________________________________________________________________
# cropping1d_4 (Cropping1D)    (None, 26, 64)            0
# _________________________________________________________________
# up_sampling1d_8 (UpSampling1 (None, 52, 64)            0
# _________________________________________________________________
# conv1d_28 (Conv1D)           (None, 52, 128)           82048
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 52, 128)           512
# _________________________________________________________________
# activation_18 (Activation)   (None, 52, 128)           0
# _________________________________________________________________
# cropping1d_5 (Cropping1D)    (None, 50, 128)           0
# _________________________________________________________________
# up_sampling1d_9 (UpSampling1 (None, 100, 128)          0
# _________________________________________________________________
# conv1d_29 (Conv1D)           (None, 100, 1)            1281
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 100, 1)            4
# _________________________________________________________________
# activation_19 (Activation)   (None, 100, 1)            0
# _________________________________________________________________
# reshape_5 (Reshape)          (None, 100, 1, 1)         0
# =================================================================
# Total params: 581,770
# Trainable params: 580,230
# Non-trainable params: 1,540
# _________________________________________________________________

# %%
class WGAN(keras.Model):
    def __init__(
        self,
        discriminator,
        generator,
        latent_dim,
        discriminator_extra_steps=5,
        gp_weight=10.0,
    ):
        super(WGAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim
        self.d_steps = discriminator_extra_steps
        self.gp_weight = gp_weight

    def compile(self, d_optimizer, g_optimizer, d_loss_fn, g_loss_fn):
        super(WGAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.d_loss_fn = d_loss_fn
        self.g_loss_fn = g_loss_fn

    def gradient_penalty(self, batch_size, real_images, fake_images):
        """ Calculates the gradient penalty.

        This loss is calculated on an interpolated image
        and added to the discriminator loss.
        """
        # Get the interpolated image
        
        alpha = tf.random.normal([batch_size, 1, 1, 1], 0.0, 1.0)
        diff = fake_images - real_images
        interpolated = real_images + alpha * diff

        with tf.GradientTape() as gp_tape:
            gp_tape.watch(interpolated)
            # 1. Get the discriminator output for this interpolated image.
            pred = self.discriminator(interpolated, training=True)

        # 2. Calculate the gradients w.r.t to this interpolated image.
        grads = gp_tape.gradient(pred, [interpolated])[0]
        # 3. Calculate the norm of the gradients.
        norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1, 2, 3]))
        gp = tf.reduce_mean((norm - 1.0) ** 2)
        return gp

    def train_step(self, real_images):
        if isinstance(real_images, tuple):
            real_images = real_images[0]

        # Get the batch size
        batch_size = tf.shape(real_images)[0]

        # For each batch, we are going to perform the
        # following steps as laid out in the original paper:
        # 1. Train the generator and get the generator loss
        # 2. Train the discriminator and get the discriminator loss
        # 3. Calculate the gradient penalty
        # 4. Multiply this gradient penalty with a constant weight factor
        # 5. Add the gradient penalty to the discriminator loss
        # 6. Return the generator and discriminator losses as a loss dictionary

        # Train the discriminator first. The original paper recommends training
        # the discriminator for `x` more steps (typically 5) as compared to
        # one step of the generator. Here we will train it for 3 extra steps
        # as compared to 5 to reduce the training time.
        for i in range(self.d_steps):
            # Get the latent vector
            random_latent_vectors = generator1(tf.random.normal(
                shape=(batch_size, self.latent_dim)), training=False)
            with tf.GradientTape() as tape:
                # Generate fake images from the latent vector
                fake_images = self.generator(random_latent_vectors, training=True)
                # Get the logits for the fake images
                fake_logits = self.discriminator(fake_images, training=True)
                # Get the logits for the real images
                real_logits = self.discriminator(real_images, training=True)

                # Calculate the discriminator loss using the fake and real image logits
                d_cost = self.d_loss_fn(real_img=real_logits, fake_img=fake_logits)
                # Calculate the gradient penalty
                gp = self.gradient_penalty(batch_size, real_images, fake_images)
                # Add the gradient penalty to the original discriminator loss
                d_loss = d_cost + gp * self.gp_weight

            # Get the gradients w.r.t the discriminator loss
            d_gradient = tape.gradient(d_loss, self.discriminator.trainable_variables)
            # Update the weights of the discriminator using the discriminator optimizer
            self.d_optimizer.apply_gradients(
                zip(d_gradient, self.discriminator.trainable_variables)
            )

        # Train the generator
        # Get the latent vector
        random_latent_vectors = generator1(tf.random.normal(
                shape=(batch_size, self.latent_dim)), training=False)
        with tf.GradientTape() as tape:
            # Generate fake images using the generator
            generated_images = self.generator(random_latent_vectors, training=True)
            # Get the discriminator logits for fake images
            gen_img_logits = self.discriminator(generated_images, training=True)
            # Calculate the generator loss
            g_loss = self.g_loss_fn(gen_img_logits)

        # Get the gradients w.r.t the generator loss
        gen_gradient = tape.gradient(g_loss, self.generator.trainable_variables)
        # Update the weights of the generator using the generator optimizer
        self.g_optimizer.apply_gradients(
            zip(gen_gradient, self.generator.trainable_variables)
        )
        return {"d_loss": d_loss, "g_loss": g_loss}

# %%
class GANMonitor(keras.callbacks.Callback):
    def __init__(self, num_img=6, latent_dim=noise_dim):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = generator1(tf.random.normal(
                shape=(BATCH_SIZE, self.latent_dim)), training=False)
        generated_images = self.model.generator(random_latent_vectors)

        plt.figure()
        for i in range(self.num_img):
            img = generated_images[i].numpy()
            plt.plot(img[:,:,0])
        #plt.savefig("D:\\BTP\\elastic_generated_series\\{epoch}.jpg".format(epoch=epoch))
        plt.close()

# %%
# Instantiate the optimizer for both networks
# (learning_rate=0.0002, beta_1=0.5 are recommended)
generator_optimizer = keras.optimizers.Adam(
    learning_rate=0.0002, beta_1=0.5, beta_2=0.9
)
discriminator_optimizer = keras.optimizers.Adam(
    learning_rate=0.0002, beta_1=0.5, beta_2=0.9
)

# Define the loss functions for the discriminator,
# which should be (fake_loss - real_loss).
# We will add the gradient penalty later to this loss function.
def discriminator_loss(real_img, fake_img):
    real_loss = tf.reduce_mean(real_img)
    fake_loss = tf.reduce_mean(fake_img)
    return fake_loss - real_loss


# Define the loss functions for the generator.
def generator_loss(fake_img):
    return -tf.reduce_mean(fake_img)


# Set the number of epochs for trainining.
epochs = 1000

# Instantiate the customer `GANMonitor` Keras callback.

## UNCOMMENT FOR COMPLETE CODE
cbk = GANMonitor(num_img=3, latent_dim=noise_dim) 

# Instantiate the WGAN model.
wgan2 = WGAN(
    discriminator=discriminator2,
    generator=generator2,
    latent_dim=noise_dim,
    discriminator_extra_steps=5,
)

# Compile the WGAN model.
wgan2.compile(
    d_optimizer=discriminator_optimizer,
    g_optimizer=generator_optimizer,
    g_loss_fn=generator_loss,
    d_loss_fn=discriminator_loss,
)

# Start training the model.
wgan2.fit(train_images, batch_size=BATCH_SIZE, epochs=epochs, callbacks=[cbk])
# Out:
# Epoch 1/1000
# 5/5 [==============================] - 24s 98ms/step - d_loss: -0.4132 - g_loss: 0.1989
# Epoch 2/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.2650 - g_loss: 0.0630
# Epoch 3/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.4197 - g_loss: 0.1027
# Epoch 4/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.2385 - g_loss: 0.2446
# Epoch 5/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3308 - g_loss: 0.2089
# Epoch 6/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2147 - g_loss: 0.1206
# Epoch 7/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3354 - g_loss: 0.2146
# Epoch 8/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.2648 - g_loss: 0.2282
# Epoch 9/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.2577 - g_loss: 0.0858
# Epoch 10/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3641 - g_loss: 0.3431
# Epoch 11/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.4318 - g_loss: 0.1494
# Epoch 12/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.2705 - g_loss: 0.2174
# Epoch 13/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3264 - g_loss: 0.1248
# Epoch 14/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.4394 - g_loss: 0.3774
# Epoch 15/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.4542 - g_loss: 0.3467
# Epoch 16/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.2742 - g_loss: 0.4747
# Epoch 17/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3974 - g_loss: 0.3725
# Epoch 18/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3554 - g_loss: 0.2311
# Epoch 19/1000
# 5/5 [==============================] - 0s 91ms/step - d_loss: -0.4265 - g_loss: 0.0525
# Epoch 20/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3793 - g_loss: 0.0594
# Epoch 21/1000
# 5/5 [==============================] - 0s 91ms/step - d_loss: -0.3915 - g_loss: 0.3679
# Epoch 22/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.2811 - g_loss: 0.1220
# Epoch 23/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.2578 - g_loss: 0.0524
# Epoch 24/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.3408 - g_loss: 0.0019
# Epoch 25/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3407 - g_loss: -0.0741
# Epoch 26/1000
# 5/5 [==============================] - 0s 91ms/step - d_loss: -0.3228 - g_loss: 0.0693
# Epoch 27/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3562 - g_loss: 0.0695
# Epoch 28/1000
# 5/5 [==============================] - 0s 90ms/step - d_loss: -0.3140 - g_loss: 0.1152
# Epoch 29/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2983 - g_loss: 0.0923
# Epoch 30/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2944 - g_loss: -0.0789
# Epoch 31/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.2898 - g_loss: -0.0391
# Epoch 32/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3023 - g_loss: 0.0995
# Epoch 33/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.2313 - g_loss: 0.0989
# Epoch 34/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3273 - g_loss: 0.1915
# Epoch 35/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3353 - g_loss: 0.3297
# Epoch 36/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.2771 - g_loss: 0.4128
# Epoch 37/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3381 - g_loss: 0.2757
# Epoch 38/1000
# 5/5 [==============================] - 0s 91ms/step - d_loss: -0.3039 - g_loss: 0.2284
# Epoch 39/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3367 - g_loss: 0.3708
# Epoch 40/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3139 - g_loss: 0.3972
# Epoch 41/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.4017 - g_loss: 0.3734
# Epoch 42/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.2426 - g_loss: 0.3513
# Epoch 43/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.4505 - g_loss: 0.2581
# Epoch 44/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.2849 - g_loss: 0.2853
# Epoch 45/1000
# 5/5 [==============================] - 0s 91ms/step - d_loss: -0.2362 - g_loss: 0.1350
# Epoch 46/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3722 - g_loss: 0.2220
# Epoch 47/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2185 - g_loss: 0.1458
# Epoch 48/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.3199 - g_loss: 0.0596
# Epoch 49/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3811 - g_loss: -0.0055
# Epoch 50/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3620 - g_loss: 0.0753
# Epoch 51/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3560 - g_loss: 0.1662
# Epoch 52/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.2010 - g_loss: 0.0690
# Epoch 53/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.2488 - g_loss: 0.1444
# Epoch 54/1000
# 5/5 [==============================] - 0s 91ms/step - d_loss: -0.4449 - g_loss: 0.4243
# Epoch 55/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3330 - g_loss: 0.3758
# Epoch 56/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.2936 - g_loss: 0.2264
# Epoch 57/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.2780 - g_loss: 0.2318
# Epoch 58/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3789 - g_loss: 0.1681
# Epoch 59/1000
# 5/5 [==============================] - 0s 91ms/step - d_loss: -0.3125 - g_loss: -0.0841
# Epoch 60/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.3383 - g_loss: 0.1053
# Epoch 61/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3356 - g_loss: 0.1986
# Epoch 62/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3789 - g_loss: 0.1189
# Epoch 63/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3719 - g_loss: 0.2719
# Epoch 64/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.4957 - g_loss: 0.1838
# Epoch 65/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3260 - g_loss: 0.1024
# Epoch 66/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.2851 - g_loss: 0.1298
# Epoch 67/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.2582 - g_loss: 0.1242
# Epoch 68/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3273 - g_loss: 0.0238
# Epoch 69/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.2969 - g_loss: -0.1418
# Epoch 70/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3987 - g_loss: 0.0339
# Epoch 71/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3722 - g_loss: 0.0124
# Epoch 72/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.4165 - g_loss: -0.0058
# Epoch 73/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.3168 - g_loss: -0.0621
# Epoch 74/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3488 - g_loss: 0.0352
# Epoch 75/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.4055 - g_loss: 0.2518
# Epoch 76/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3194 - g_loss: 0.1585
# Epoch 77/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.4814 - g_loss: 0.0677
# Epoch 78/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3570 - g_loss: -0.1034
# Epoch 79/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3676 - g_loss: 0.0139
# Epoch 80/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2636 - g_loss: -0.0118
# Epoch 81/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3405 - g_loss: -0.2023
# Epoch 82/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.1924 - g_loss: -0.3309
# Epoch 83/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.2004 - g_loss: -0.0492
# Epoch 84/1000
# 5/5 [==============================] - 0s 101ms/step - d_loss: -0.3838 - g_loss: 0.0448
# Epoch 85/1000
# 5/5 [==============================] - 0s 90ms/step - d_loss: -0.4169 - g_loss: 0.4209
# Epoch 86/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.4510 - g_loss: 0.0570
# Epoch 87/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2693 - g_loss: 0.1814
# Epoch 88/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.5032 - g_loss: 0.2890
# Epoch 89/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.4976 - g_loss: 0.2983
# Epoch 90/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.5124 - g_loss: 0.3375
# Epoch 91/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3439 - g_loss: 0.2901
# Epoch 92/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.5666 - g_loss: 0.2256
# Epoch 93/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.4271 - g_loss: 0.1973
# Epoch 94/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.6074 - g_loss: 0.1829
# Epoch 95/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.4142 - g_loss: 0.3136
# Epoch 96/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3478 - g_loss: 0.2858
# Epoch 97/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3393 - g_loss: 0.1447
# Epoch 98/1000
# 5/5 [==============================] - 0s 91ms/step - d_loss: -0.2738 - g_loss: 0.2715
# Epoch 99/1000
# 5/5 [==============================] - 1s 99ms/step - d_loss: -0.3622 - g_loss: 0.2708
# Epoch 100/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.4792 - g_loss: 0.1626
# Epoch 101/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3851 - g_loss: 0.2719
# Epoch 102/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.4806 - g_loss: 0.2122
# Epoch 103/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3946 - g_loss: 0.2752
# Epoch 104/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.3258 - g_loss: 0.1896
# Epoch 105/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3578 - g_loss: -0.0343
# Epoch 106/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2766 - g_loss: 0.2380
# Epoch 107/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3535 - g_loss: 0.3327
# Epoch 108/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3676 - g_loss: 0.2807
# Epoch 109/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.4338 - g_loss: 0.1783
# Epoch 110/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.4576 - g_loss: 0.2220
# Epoch 111/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.4358 - g_loss: 0.2842
# Epoch 112/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.4025 - g_loss: 0.0889
# Epoch 113/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2483 - g_loss: 0.1459
# Epoch 114/1000
# 5/5 [==============================] - 1s 99ms/step - d_loss: -0.3165 - g_loss: 0.0638
# Epoch 115/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.5665 - g_loss: 0.3918
# Epoch 116/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3915 - g_loss: 0.7362
# Epoch 117/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.4199 - g_loss: 0.2987
# Epoch 118/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3191 - g_loss: 0.0949
# Epoch 119/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3857 - g_loss: 0.0285
# Epoch 120/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3231 - g_loss: 0.0087
# Epoch 121/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3072 - g_loss: 0.0605
# Epoch 122/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3667 - g_loss: 0.1373
# Epoch 123/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.3930 - g_loss: 0.1071
# Epoch 124/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3855 - g_loss: 0.0692
# Epoch 125/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.4429 - g_loss: 0.2982
# Epoch 126/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3382 - g_loss: 0.1649
# Epoch 127/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.5256 - g_loss: 0.4283
# Epoch 128/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.4065 - g_loss: 0.3610
# Epoch 129/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3342 - g_loss: 0.0908
# Epoch 130/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3645 - g_loss: -0.1250
# Epoch 131/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.2125 - g_loss: -0.0963
# Epoch 132/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3513 - g_loss: 0.2717
# Epoch 133/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3718 - g_loss: 0.3783
# Epoch 134/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3742 - g_loss: 0.1463
# Epoch 135/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3634 - g_loss: 0.2517
# Epoch 136/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.4047 - g_loss: 0.4900
# Epoch 137/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3201 - g_loss: 0.4960
# Epoch 138/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3560 - g_loss: 0.2596
# Epoch 139/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.4148 - g_loss: 0.2079
# Epoch 140/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.4928 - g_loss: 0.3915
# Epoch 141/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.4243 - g_loss: 0.4152
# Epoch 142/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.2313 - g_loss: -0.0215
# Epoch 143/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2850 - g_loss: 0.2061
# Epoch 144/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2725 - g_loss: 0.2638
# Epoch 145/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3189 - g_loss: 0.4239
# Epoch 146/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2879 - g_loss: 0.1156
# Epoch 147/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3102 - g_loss: 0.0460
# Epoch 148/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3383 - g_loss: 0.0178
# Epoch 149/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3023 - g_loss: -0.0110
# Epoch 150/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.2406 - g_loss: 0.0630
# Epoch 151/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3679 - g_loss: 0.0091
# Epoch 152/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3470 - g_loss: -0.0865
# Epoch 153/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3643 - g_loss: 0.0982
# Epoch 154/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.4446 - g_loss: -0.1451
# Epoch 155/1000
# 5/5 [==============================] - 0s 91ms/step - d_loss: -0.3425 - g_loss: 0.0279
# Epoch 156/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3864 - g_loss: 0.1027
# Epoch 157/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3471 - g_loss: 0.0654
# Epoch 158/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3766 - g_loss: 0.1433
# Epoch 159/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3237 - g_loss: 0.2883
# Epoch 160/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3331 - g_loss: 0.2750
# Epoch 161/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3092 - g_loss: 0.2225
# Epoch 162/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.5016 - g_loss: 0.0712
# Epoch 163/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2664 - g_loss: 0.1332
# Epoch 164/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.4036 - g_loss: 0.2690
# Epoch 165/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2886 - g_loss: 0.1319
# Epoch 166/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3331 - g_loss: 0.1206
# Epoch 167/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.4966 - g_loss: 0.1580
# Epoch 168/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3765 - g_loss: 0.2501
# Epoch 169/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.4464 - g_loss: 0.4395
# Epoch 170/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.4608 - g_loss: 0.3107
# Epoch 171/1000
# 5/5 [==============================] - 0s 91ms/step - d_loss: -0.3376 - g_loss: 0.3555
# Epoch 172/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.5024 - g_loss: 0.0820
# Epoch 173/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.5345 - g_loss: 0.1654
# Epoch 174/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.2220 - g_loss: 0.3181
# Epoch 175/1000
# 5/5 [==============================] - 1s 105ms/step - d_loss: -0.4448 - g_loss: 0.4374
# Epoch 176/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.4866 - g_loss: 0.4478
# Epoch 177/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3613 - g_loss: 0.4354
# Epoch 178/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.4557 - g_loss: 0.2400
# Epoch 179/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.4391 - g_loss: 0.3652
# Epoch 180/1000
# 5/5 [==============================] - 0s 91ms/step - d_loss: -0.4433 - g_loss: 0.0813
# Epoch 181/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.4350 - g_loss: 0.0895
# Epoch 182/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3891 - g_loss: 0.2732
# Epoch 183/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.4569 - g_loss: 0.4166
# Epoch 184/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.4488 - g_loss: 0.4568
# Epoch 185/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3098 - g_loss: 0.3455
# Epoch 186/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.4032 - g_loss: 0.1189
# Epoch 187/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3587 - g_loss: 0.0674
# Epoch 188/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3178 - g_loss: 0.2716
# Epoch 189/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.4106 - g_loss: 0.3839
# Epoch 190/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.4124 - g_loss: 0.0759
# Epoch 191/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3244 - g_loss: -0.0116
# Epoch 192/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3592 - g_loss: -0.0138
# Epoch 193/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3759 - g_loss: 0.1387
# Epoch 194/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3771 - g_loss: 0.0854
# Epoch 195/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.4176 - g_loss: 0.3583
# Epoch 196/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3303 - g_loss: 0.3366
# Epoch 197/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3521 - g_loss: 0.0952
# Epoch 198/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3424 - g_loss: 0.0433
# Epoch 199/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2889 - g_loss: 0.0864
# Epoch 200/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.3399 - g_loss: 0.0343
# Epoch 201/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3168 - g_loss: -0.0528
# Epoch 202/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3517 - g_loss: 0.2095
# Epoch 203/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.3595 - g_loss: 0.2422
# Epoch 204/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3898 - g_loss: 0.2841
# Epoch 205/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.4831 - g_loss: 0.3566
# Epoch 206/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3557 - g_loss: 0.3178
# Epoch 207/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.4745 - g_loss: 0.3914
# Epoch 208/1000
# 5/5 [==============================] - 0s 91ms/step - d_loss: -0.4144 - g_loss: 0.3084
# Epoch 209/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3044 - g_loss: 0.0732
# Epoch 210/1000
# 5/5 [==============================] - 0s 91ms/step - d_loss: -0.3011 - g_loss: 0.1053
# Epoch 211/1000
# 5/5 [==============================] - 0s 101ms/step - d_loss: -0.3957 - g_loss: 0.0916
# Epoch 212/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3705 - g_loss: 0.1914
# Epoch 213/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2587 - g_loss: 0.0844
# Epoch 214/1000
# 5/5 [==============================] - 0s 91ms/step - d_loss: -0.2520 - g_loss: 0.1928
# Epoch 215/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.2761 - g_loss: 0.0782
# Epoch 216/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.4033 - g_loss: 0.1906
# Epoch 217/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3323 - g_loss: 0.0243
# Epoch 218/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2265 - g_loss: -0.0529
# Epoch 219/1000
# 5/5 [==============================] - 1s 100ms/step - d_loss: -0.3782 - g_loss: -0.0136
# Epoch 220/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.4162 - g_loss: -0.0326
# Epoch 221/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.4299 - g_loss: 0.0397
# Epoch 222/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.4382 - g_loss: 0.1502
# Epoch 223/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.4128 - g_loss: 0.2658
# Epoch 224/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.2760 - g_loss: 0.0858
# Epoch 225/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3983 - g_loss: 0.2635
# Epoch 226/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3286 - g_loss: 0.1673
# Epoch 227/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3732 - g_loss: 0.0179
# Epoch 228/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3029 - g_loss: -0.1480
# Epoch 229/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3020 - g_loss: -0.0072
# Epoch 230/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.1986 - g_loss: 0.0949
# Epoch 231/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3472 - g_loss: 0.1337
# Epoch 232/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3444 - g_loss: 0.2367
# Epoch 233/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3525 - g_loss: 0.1319
# Epoch 234/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.4420 - g_loss: 0.3631
# Epoch 235/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.4383 - g_loss: 0.1708
# Epoch 236/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.2896 - g_loss: 0.1366
# Epoch 237/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3378 - g_loss: 0.0382
# Epoch 238/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3213 - g_loss: 0.0119
# Epoch 239/1000
# 5/5 [==============================] - 1s 104ms/step - d_loss: -0.4057 - g_loss: 0.2801
# Epoch 240/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3717 - g_loss: 0.2842
# Epoch 241/1000
# 5/5 [==============================] - 1s 100ms/step - d_loss: -0.3411 - g_loss: -0.0342
# Epoch 242/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3582 - g_loss: -0.0297
# Epoch 243/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2612 - g_loss: -0.1149
# Epoch 244/1000
# 5/5 [==============================] - 1s 100ms/step - d_loss: -0.3588 - g_loss: 0.0624
# Epoch 245/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3847 - g_loss: 0.0887
# Epoch 246/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3362 - g_loss: 0.0448
# Epoch 247/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3145 - g_loss: 0.0881
# Epoch 248/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2356 - g_loss: 0.1168
# Epoch 249/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3703 - g_loss: 0.2389
# Epoch 250/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.2857 - g_loss: 0.2191
# Epoch 251/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.4904 - g_loss: 0.1389
# Epoch 252/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3211 - g_loss: -0.0010
# Epoch 253/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.4141 - g_loss: 0.0175
# Epoch 254/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3820 - g_loss: 0.1901
# Epoch 255/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2407 - g_loss: 0.0067
# Epoch 256/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3011 - g_loss: 0.1430
# Epoch 257/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3840 - g_loss: 0.0589
# Epoch 258/1000
# 5/5 [==============================] - 0s 90ms/step - d_loss: -0.3655 - g_loss: -0.1064
# Epoch 259/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.2856 - g_loss: 0.1331
# Epoch 260/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3636 - g_loss: -0.0414
# Epoch 261/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3361 - g_loss: 0.0564
# Epoch 262/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3957 - g_loss: 0.1288
# Epoch 263/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2229 - g_loss: 0.1982
# Epoch 264/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3153 - g_loss: 0.2013
# Epoch 265/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3464 - g_loss: 0.1777
# Epoch 266/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.3969 - g_loss: 0.1895
# Epoch 267/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3706 - g_loss: 0.0360
# Epoch 268/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.1971 - g_loss: 0.0187
# Epoch 269/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.1762 - g_loss: -0.0137
# Epoch 270/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3090 - g_loss: 0.1624
# Epoch 271/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.3630 - g_loss: 0.1191
# Epoch 272/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.4078 - g_loss: 0.0774
# Epoch 273/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3773 - g_loss: 0.0829
# Epoch 274/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3362 - g_loss: 0.0786
# Epoch 275/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3903 - g_loss: 0.1412
# Epoch 276/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3231 - g_loss: 0.1869
# Epoch 277/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3145 - g_loss: 0.0268
# Epoch 278/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3468 - g_loss: -0.0208
# Epoch 279/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3591 - g_loss: 0.1597
# Epoch 280/1000
# 5/5 [==============================] - 0s 101ms/step - d_loss: -0.2155 - g_loss: 0.1100
# Epoch 281/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.4763 - g_loss: 0.1797
# Epoch 282/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.2688 - g_loss: 0.0436
# Epoch 283/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.4176 - g_loss: 0.0912
# Epoch 284/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3102 - g_loss: 0.2467
# Epoch 285/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.4335 - g_loss: 0.2929
# Epoch 286/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3799 - g_loss: 0.2313
# Epoch 287/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3962 - g_loss: 0.1879
# Epoch 288/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3865 - g_loss: 0.1295
# Epoch 289/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.5306 - g_loss: 0.0749
# Epoch 290/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3250 - g_loss: 0.0808
# Epoch 291/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3683 - g_loss: 0.0093
# Epoch 292/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.5743 - g_loss: -0.0226
# Epoch 293/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3883 - g_loss: 0.1366
# Epoch 294/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3285 - g_loss: 0.1077
# Epoch 295/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3769 - g_loss: 0.0752
# Epoch 296/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3731 - g_loss: 0.0461
# Epoch 297/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3903 - g_loss: -0.0554
# Epoch 298/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3761 - g_loss: 0.0469
# Epoch 299/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.4547 - g_loss: -0.0060
# Epoch 300/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.5706 - g_loss: 0.0539
# Epoch 301/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3753 - g_loss: 0.1340
# Epoch 302/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3417 - g_loss: 0.0215
# Epoch 303/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.3784 - g_loss: 0.0894
# Epoch 304/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3139 - g_loss: 0.1165
# Epoch 305/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3306 - g_loss: 0.0631
# Epoch 306/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.2846 - g_loss: 0.1322
# Epoch 307/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.4330 - g_loss: 0.1567
# Epoch 308/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.4505 - g_loss: 0.2088
# Epoch 309/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.4242 - g_loss: 0.1433
# Epoch 310/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3576 - g_loss: 0.2263
# Epoch 311/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3342 - g_loss: 0.2014
# Epoch 312/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.2444 - g_loss: 0.1370
# Epoch 313/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.3314 - g_loss: 0.2538
# Epoch 314/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.5025 - g_loss: 0.2218
# Epoch 315/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3838 - g_loss: 0.3138
# Epoch 316/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3016 - g_loss: 0.2585
# Epoch 317/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3713 - g_loss: 0.2550
# Epoch 318/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2590 - g_loss: 0.2578
# Epoch 319/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.2896 - g_loss: 0.3560
# Epoch 320/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.4484 - g_loss: 0.2132
# Epoch 321/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3232 - g_loss: 0.3206
# Epoch 322/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.4420 - g_loss: 0.3083
# Epoch 323/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.4512 - g_loss: 0.0794
# Epoch 324/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3763 - g_loss: -0.0010
# Epoch 325/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.2699 - g_loss: 0.1369
# Epoch 326/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.5143 - g_loss: 0.3126
# Epoch 327/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.4987 - g_loss: 0.2743
# Epoch 328/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3468 - g_loss: 0.0606
# Epoch 329/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3035 - g_loss: 0.1608
# Epoch 330/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3253 - g_loss: 0.1368
# Epoch 331/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3211 - g_loss: 0.0359
# Epoch 332/1000
# 5/5 [==============================] - 1s 105ms/step - d_loss: -0.3772 - g_loss: 0.0762
# Epoch 333/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.4431 - g_loss: 0.1064
# Epoch 334/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3545 - g_loss: 0.1275
# Epoch 335/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3751 - g_loss: 0.0773
# Epoch 336/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3288 - g_loss: 0.2776
# Epoch 337/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3915 - g_loss: 0.3586
# Epoch 338/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.5135 - g_loss: 0.4147
# Epoch 339/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.4490 - g_loss: 0.1838
# Epoch 340/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3249 - g_loss: 0.1918
# Epoch 341/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.1750 - g_loss: 0.0487
# Epoch 342/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.4810 - g_loss: -0.0013
# Epoch 343/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3115 - g_loss: 0.0617
# Epoch 344/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3298 - g_loss: 0.0424
# Epoch 345/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.4566 - g_loss: 0.1060
# Epoch 346/1000
# 5/5 [==============================] - 0s 92ms/step - d_loss: -0.5164 - g_loss: -0.0173
# Epoch 347/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.4695 - g_loss: 0.0466
# Epoch 348/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3546 - g_loss: -0.0066
# Epoch 349/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.5737 - g_loss: -0.0100
# Epoch 350/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.4273 - g_loss: -0.1656
# Epoch 351/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.4375 - g_loss: -0.0379
# Epoch 352/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.4493 - g_loss: -0.0220
# Epoch 353/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.4843 - g_loss: 0.1853
# Epoch 354/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.4342 - g_loss: -0.0113
# Epoch 355/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.3560 - g_loss: 0.2136
# Epoch 356/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2963 - g_loss: 0.0415
# Epoch 357/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.4211 - g_loss: 0.1161
# Epoch 358/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3308 - g_loss: 0.1867
# Epoch 359/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3266 - g_loss: 0.2410
# Epoch 360/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3670 - g_loss: 0.3007
# Epoch 361/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3705 - g_loss: 0.0542
# Epoch 362/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.4893 - g_loss: 0.1199
# Epoch 363/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.4796 - g_loss: 0.1463
# Epoch 364/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.2780 - g_loss: 0.1217
# Epoch 365/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.2193 - g_loss: 0.1312
# Epoch 366/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2919 - g_loss: 0.0923
# Epoch 367/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2863 - g_loss: 0.0534
# Epoch 368/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2135 - g_loss: -0.0362
# Epoch 369/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3133 - g_loss: 0.1343
# Epoch 370/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3634 - g_loss: 0.2113
# Epoch 371/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3969 - g_loss: 0.1836
# Epoch 372/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.2758 - g_loss: 0.2367
# Epoch 373/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3107 - g_loss: 0.0413
# Epoch 374/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.4236 - g_loss: 0.0808
# Epoch 375/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3984 - g_loss: 0.2134
# Epoch 376/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.4980 - g_loss: 0.2319
# Epoch 377/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3379 - g_loss: 0.3323
# Epoch 378/1000
# 5/5 [==============================] - 0s 93ms/step - d_loss: -0.3736 - g_loss: 0.3445
# Epoch 379/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.5059 - g_loss: 0.2351
# Epoch 380/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3688 - g_loss: 0.2315
# Epoch 381/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3127 - g_loss: 0.1254
# Epoch 382/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.5243 - g_loss: 0.2764
# Epoch 383/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3881 - g_loss: 0.3924
# Epoch 384/1000
# 5/5 [==============================] - 0s 102ms/step - d_loss: -0.2431 - g_loss: 0.2119
# Epoch 385/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3178 - g_loss: 0.2025
# Epoch 386/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3087 - g_loss: 0.2391
# Epoch 387/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3909 - g_loss: 0.2911
# Epoch 388/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.4630 - g_loss: 0.1926
# Epoch 389/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3697 - g_loss: 0.2807
# Epoch 390/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.4209 - g_loss: 0.1349
# Epoch 391/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3394 - g_loss: 0.2028
# Epoch 392/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.2442 - g_loss: 0.1806
# Epoch 393/1000
# 5/5 [==============================] - 0s 101ms/step - d_loss: -0.4719 - g_loss: 0.1486
# Epoch 394/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3245 - g_loss: 0.1408
# Epoch 395/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.4371 - g_loss: 0.2311
# Epoch 396/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3335 - g_loss: 0.2178
# Epoch 397/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.4071 - g_loss: 0.1902
# Epoch 398/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.4110 - g_loss: 0.1239
# Epoch 399/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.2616 - g_loss: 0.2101
# Epoch 400/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.2594 - g_loss: 0.4259
# Epoch 401/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3867 - g_loss: 0.2741
# Epoch 402/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.2603 - g_loss: 0.3944
# Epoch 403/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3580 - g_loss: 0.1727
# Epoch 404/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3746 - g_loss: 0.1888
# Epoch 405/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3690 - g_loss: 0.2605
# Epoch 406/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.4374 - g_loss: 0.4085
# Epoch 407/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.2394 - g_loss: 0.1234
# Epoch 408/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3453 - g_loss: 0.0897
# Epoch 409/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2698 - g_loss: 0.1231
# Epoch 410/1000
# 5/5 [==============================] - 1s 105ms/step - d_loss: -0.2955 - g_loss: 0.3000
# Epoch 411/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3265 - g_loss: 0.2370
# Epoch 412/1000
# 5/5 [==============================] - 1s 99ms/step - d_loss: -0.2299 - g_loss: 0.0836
# Epoch 413/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3948 - g_loss: 0.2026
# Epoch 414/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3841 - g_loss: 0.1736
# Epoch 415/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.3910 - g_loss: 0.2551
# Epoch 416/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.2373 - g_loss: 0.1614
# Epoch 417/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3555 - g_loss: 0.1341
# Epoch 418/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3244 - g_loss: 0.2276
# Epoch 419/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3190 - g_loss: 0.2320
# Epoch 420/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.4381 - g_loss: 0.1327
# Epoch 421/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3671 - g_loss: -0.0222
# Epoch 422/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3636 - g_loss: 0.0056
# Epoch 423/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3839 - g_loss: 0.2452
# Epoch 424/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3224 - g_loss: 0.0641
# Epoch 425/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.4100 - g_loss: 0.2236
# Epoch 426/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.4103 - g_loss: 0.2382
# Epoch 427/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.4113 - g_loss: 0.0557
# Epoch 428/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3044 - g_loss: 0.1293
# Epoch 429/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2576 - g_loss: 0.0318
# Epoch 430/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.2467 - g_loss: 0.0258
# Epoch 431/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2202 - g_loss: 0.0420
# Epoch 432/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3086 - g_loss: -0.0298
# Epoch 433/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3795 - g_loss: 0.1287
# Epoch 434/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.4170 - g_loss: 0.1863
# Epoch 435/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3861 - g_loss: 0.1465
# Epoch 436/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.4476 - g_loss: 0.1472
# Epoch 437/1000
# 5/5 [==============================] - 0s 101ms/step - d_loss: -0.3768 - g_loss: 0.2376
# Epoch 438/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3815 - g_loss: 0.2293
# Epoch 439/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.2954 - g_loss: 0.1207
# Epoch 440/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.3774 - g_loss: 0.3203
# Epoch 441/1000
# 5/5 [==============================] - 1s 106ms/step - d_loss: -0.2400 - g_loss: 0.2743
# Epoch 442/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2846 - g_loss: 0.2673
# Epoch 443/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3058 - g_loss: 0.1144
# Epoch 444/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2794 - g_loss: 0.2877
# Epoch 445/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3514 - g_loss: 0.3008
# Epoch 446/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3409 - g_loss: 0.1592
# Epoch 447/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.4248 - g_loss: 0.1000
# Epoch 448/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3845 - g_loss: 0.0326
# Epoch 449/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.4454 - g_loss: 0.0384
# Epoch 450/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.4140 - g_loss: -0.0122
# Epoch 451/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2735 - g_loss: -0.1310
# Epoch 452/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.3119 - g_loss: -0.0945
# Epoch 453/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.2270 - g_loss: 0.0958
# Epoch 454/1000
# 5/5 [==============================] - 1s 106ms/step - d_loss: -0.2345 - g_loss: 0.0874
# Epoch 455/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3078 - g_loss: 0.0985
# Epoch 456/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3302 - g_loss: 0.0847
# Epoch 457/1000
# 5/5 [==============================] - 0s 101ms/step - d_loss: -0.3425 - g_loss: 0.2246
# Epoch 458/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2913 - g_loss: 0.2888
# Epoch 459/1000
# 5/5 [==============================] - 1s 105ms/step - d_loss: -0.3877 - g_loss: 0.0729
# Epoch 460/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2426 - g_loss: 0.1031
# Epoch 461/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3420 - g_loss: 0.0547
# Epoch 462/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3756 - g_loss: 0.1518
# Epoch 463/1000
# 5/5 [==============================] - 0s 101ms/step - d_loss: -0.3228 - g_loss: 0.1561
# Epoch 464/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3684 - g_loss: 0.1608
# Epoch 465/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2755 - g_loss: 0.1683
# Epoch 466/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3710 - g_loss: 0.1686
# Epoch 467/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.4109 - g_loss: -0.0717
# Epoch 468/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.3036 - g_loss: 0.0782
# Epoch 469/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.1623 - g_loss: 0.2361
# Epoch 470/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.3317 - g_loss: 0.3212
# Epoch 471/1000
# ...
# Epoch 847/1000
# 5/5 [==============================] - 0s 101ms/step - d_loss: -0.2350 - g_loss: 0.0172
# Epoch 848/1000
# 5/5 [==============================] - 1s 106ms/step - d_loss: -0.3701 - g_loss: -0.0304
# Epoch 849/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3141 - g_loss: 0.0498
# Epoch 850/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.2814 - g_loss: 0.0751
# Epoch 851/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.3942 - g_loss: 0.0356
# Epoch 852/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3494 - g_loss: -0.0706
# Epoch 853/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3789 - g_loss: -0.0879
# Epoch 854/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.2952 - g_loss: -0.2090
# Epoch 855/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.3353 - g_loss: -0.1760
# Epoch 856/1000
# 5/5 [==============================] - 1s 105ms/step - d_loss: -0.3679 - g_loss: -0.1175
# Epoch 857/1000
# 5/5 [==============================] - 1s 106ms/step - d_loss: -0.3853 - g_loss: -0.1409
# Epoch 858/1000
# 5/5 [==============================] - 1s 104ms/step - d_loss: -0.4385 - g_loss: -0.1891
# Epoch 859/1000
# 5/5 [==============================] - 1s 108ms/step - d_loss: -0.4132 - g_loss: -0.2625
# Epoch 860/1000
# 5/5 [==============================] - 1s 107ms/step - d_loss: -0.2595 - g_loss: -0.1767
# Epoch 861/1000
# 5/5 [==============================] - 1s 104ms/step - d_loss: -0.3097 - g_loss: -0.0512
# Epoch 862/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.4287 - g_loss: -0.0382
# Epoch 863/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.4538 - g_loss: -0.1655
# Epoch 864/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.4081 - g_loss: -0.0799
# Epoch 865/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.3313 - g_loss: -0.0865
# Epoch 866/1000
# 5/5 [==============================] - 1s 104ms/step - d_loss: -0.3990 - g_loss: -0.0902
# Epoch 867/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.2869 - g_loss: -0.1647
# Epoch 868/1000
# 5/5 [==============================] - 1s 108ms/step - d_loss: -0.3234 - g_loss: -0.0423
# Epoch 869/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3959 - g_loss: -0.0251
# Epoch 870/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3512 - g_loss: 0.0584
# Epoch 871/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.4375 - g_loss: -0.0595
# Epoch 872/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3875 - g_loss: -0.1843
# Epoch 873/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.3283 - g_loss: -0.0641
# Epoch 874/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.4206 - g_loss: 0.0941
# Epoch 875/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.2661 - g_loss: -0.0110
# Epoch 876/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.4770 - g_loss: -0.0394
# Epoch 877/1000
# 5/5 [==============================] - 1s 107ms/step - d_loss: -0.2818 - g_loss: -0.1089
# Epoch 878/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.4023 - g_loss: -0.0125
# Epoch 879/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.3748 - g_loss: -0.0697
# Epoch 880/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.3609 - g_loss: -0.0969
# Epoch 881/1000
# 5/5 [==============================] - 1s 108ms/step - d_loss: -0.3444 - g_loss: -0.0454
# Epoch 882/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.3087 - g_loss: -0.1292
# Epoch 883/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.3454 - g_loss: 0.0439
# Epoch 884/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3963 - g_loss: 0.0657
# Epoch 885/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3171 - g_loss: 0.0317
# Epoch 886/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.2938 - g_loss: 0.0010
# Epoch 887/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.4309 - g_loss: -0.1439
# Epoch 888/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3407 - g_loss: -0.0584
# Epoch 889/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.3007 - g_loss: -0.1160
# Epoch 890/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3383 - g_loss: -0.1417
# Epoch 891/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.3309 - g_loss: -0.1525
# Epoch 892/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3304 - g_loss: -0.0811
# Epoch 893/1000
# 5/5 [==============================] - 1s 106ms/step - d_loss: -0.3392 - g_loss: -0.0341
# Epoch 894/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.3873 - g_loss: -0.0346
# Epoch 895/1000
# 5/5 [==============================] - 0s 101ms/step - d_loss: -0.4685 - g_loss: 0.0812
# Epoch 896/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3353 - g_loss: -0.1114
# Epoch 897/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.4052 - g_loss: -0.0559
# Epoch 898/1000
# 5/5 [==============================] - 0s 94ms/step - d_loss: -0.2824 - g_loss: 0.0182
# Epoch 899/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.5252 - g_loss: 0.2027
# Epoch 900/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.5342 - g_loss: 0.0846
# Epoch 901/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.4524 - g_loss: -0.0324
# Epoch 902/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.2875 - g_loss: -0.0913
# Epoch 903/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.3404 - g_loss: 0.1626
# Epoch 904/1000
# 5/5 [==============================] - 1s 104ms/step - d_loss: -0.3507 - g_loss: 0.0894
# Epoch 905/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.3723 - g_loss: 0.1581
# Epoch 906/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.2929 - g_loss: -0.0397
# Epoch 907/1000
# 5/5 [==============================] - 1s 100ms/step - d_loss: -0.4090 - g_loss: -0.0307
# Epoch 908/1000
# 5/5 [==============================] - 1s 100ms/step - d_loss: -0.4160 - g_loss: -0.0796
# Epoch 909/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3187 - g_loss: -0.0194
# Epoch 910/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.4039 - g_loss: -0.0949
# Epoch 911/1000
# 5/5 [==============================] - 1s 104ms/step - d_loss: -0.3173 - g_loss: 0.1793
# Epoch 912/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.3871 - g_loss: 0.0847
# Epoch 913/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3798 - g_loss: 0.1953
# Epoch 914/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.3589 - g_loss: 0.0355
# Epoch 915/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3588 - g_loss: -0.0667
# Epoch 916/1000
# 5/5 [==============================] - 1s 105ms/step - d_loss: -0.2549 - g_loss: 0.0027
# Epoch 917/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.2055 - g_loss: 0.0909
# Epoch 918/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.5732 - g_loss: 0.1213
# Epoch 919/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3510 - g_loss: 0.0349
# Epoch 920/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.2813 - g_loss: -0.0094
# Epoch 921/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2983 - g_loss: 0.0618
# Epoch 922/1000
# 5/5 [==============================] - 0s 95ms/step - d_loss: -0.3367 - g_loss: 0.0355
# Epoch 923/1000
# 5/5 [==============================] - 0s 101ms/step - d_loss: -0.4138 - g_loss: -0.0484
# Epoch 924/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.3703 - g_loss: -0.0342
# Epoch 925/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.3394 - g_loss: -0.1432
# Epoch 926/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.3268 - g_loss: -0.1472
# Epoch 927/1000
# 5/5 [==============================] - 1s 104ms/step - d_loss: -0.3414 - g_loss: -0.0376
# Epoch 928/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.4896 - g_loss: -0.1001
# Epoch 929/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.3677 - g_loss: 0.0954
# Epoch 930/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.3603 - g_loss: 0.0878
# Epoch 931/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3700 - g_loss: 0.1588
# Epoch 932/1000
# 5/5 [==============================] - 0s 102ms/step - d_loss: -0.3783 - g_loss: -0.0638
# Epoch 933/1000
# 5/5 [==============================] - 1s 100ms/step - d_loss: -0.5451 - g_loss: -0.0738
# Epoch 934/1000
# 5/5 [==============================] - 1s 104ms/step - d_loss: -0.4078 - g_loss: -0.0057
# Epoch 935/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.5185 - g_loss: -0.0680
# Epoch 936/1000
# 5/5 [==============================] - 1s 106ms/step - d_loss: -0.4118 - g_loss: -0.0691
# Epoch 937/1000
# 5/5 [==============================] - 0s 97ms/step - d_loss: -0.2709 - g_loss: 0.0842
# Epoch 938/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.2425 - g_loss: 0.0156
# Epoch 939/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.4238 - g_loss: -0.0524
# Epoch 940/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3735 - g_loss: -0.0262
# Epoch 941/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3830 - g_loss: 0.0483
# Epoch 942/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.4078 - g_loss: 0.0243
# Epoch 943/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.2448 - g_loss: 0.1449
# Epoch 944/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.3791 - g_loss: 0.0282
# Epoch 945/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.3496 - g_loss: 0.0431
# Epoch 946/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.3364 - g_loss: 0.0659
# Epoch 947/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3523 - g_loss: 0.0471
# Epoch 948/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.4312 - g_loss: 0.0459
# Epoch 949/1000
# 5/5 [==============================] - 0s 98ms/step - d_loss: -0.3844 - g_loss: 0.1952
# Epoch 950/1000
# 5/5 [==============================] - 0s 102ms/step - d_loss: -0.4009 - g_loss: 0.0085
# Epoch 951/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.4310 - g_loss: 0.1430
# Epoch 952/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.2436 - g_loss: -0.0354
# Epoch 953/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.4016 - g_loss: -0.0300
# Epoch 954/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3843 - g_loss: 0.0710
# Epoch 955/1000
# 5/5 [==============================] - 1s 104ms/step - d_loss: -0.3116 - g_loss: -0.1067
# Epoch 956/1000
# 5/5 [==============================] - 1s 105ms/step - d_loss: -0.4118 - g_loss: -0.0469
# Epoch 957/1000
# 5/5 [==============================] - 1s 108ms/step - d_loss: -0.4960 - g_loss: -0.3271
# Epoch 958/1000
# 5/5 [==============================] - 1s 104ms/step - d_loss: -0.3216 - g_loss: -0.2168
# Epoch 959/1000
# 5/5 [==============================] - 1s 104ms/step - d_loss: -0.3953 - g_loss: -0.2383
# Epoch 960/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.2365 - g_loss: -0.0125
# Epoch 961/1000
# 5/5 [==============================] - 1s 104ms/step - d_loss: -0.3874 - g_loss: -0.0154
# Epoch 962/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.3085 - g_loss: 0.0178
# Epoch 963/1000
# 5/5 [==============================] - 1s 104ms/step - d_loss: -0.4223 - g_loss: -0.0124
# Epoch 964/1000
# 5/5 [==============================] - 1s 106ms/step - d_loss: -0.3952 - g_loss: -0.0646
# Epoch 965/1000
# 5/5 [==============================] - 1s 104ms/step - d_loss: -0.4354 - g_loss: 0.1020
# Epoch 966/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3834 - g_loss: -0.1878
# Epoch 967/1000
# 5/5 [==============================] - 0s 102ms/step - d_loss: -0.4620 - g_loss: -0.1433
# Epoch 968/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.2324 - g_loss: -0.1272
# Epoch 969/1000
# 5/5 [==============================] - 1s 105ms/step - d_loss: -0.2997 - g_loss: -0.1171
# Epoch 970/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.4116 - g_loss: -0.0937
# Epoch 971/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.3665 - g_loss: -0.1316
# Epoch 972/1000
# 5/5 [==============================] - 1s 104ms/step - d_loss: -0.3238 - g_loss: -0.1449
# Epoch 973/1000
# 5/5 [==============================] - 0s 101ms/step - d_loss: -0.3339 - g_loss: -0.2044
# Epoch 974/1000
# 5/5 [==============================] - 1s 101ms/step - d_loss: -0.4084 - g_loss: -0.1496
# Epoch 975/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.4704 - g_loss: -0.0971
# Epoch 976/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.4280 - g_loss: -0.1319
# Epoch 977/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.3596 - g_loss: -0.1917
# Epoch 978/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.3600 - g_loss: -0.1427
# Epoch 979/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.4616 - g_loss: 3.5482e-04
# Epoch 980/1000
# 5/5 [==============================] - 0s 99ms/step - d_loss: -0.4467 - g_loss: -0.0289
# Epoch 981/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.3766 - g_loss: -0.0372
# Epoch 982/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.5765 - g_loss: -0.0162
# Epoch 983/1000
# 5/5 [==============================] - 1s 105ms/step - d_loss: -0.2369 - g_loss: 0.0625
# Epoch 984/1000
# 5/5 [==============================] - 1s 104ms/step - d_loss: -0.2836 - g_loss: 0.0106
# Epoch 985/1000
# 5/5 [==============================] - 1s 106ms/step - d_loss: -0.3183 - g_loss: -0.0087
# Epoch 986/1000
# 5/5 [==============================] - 1s 105ms/step - d_loss: -0.2686 - g_loss: -0.1195
# Epoch 987/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.4869 - g_loss: -0.1678
# Epoch 988/1000
# 5/5 [==============================] - 1s 105ms/step - d_loss: -0.2966 - g_loss: 0.0119
# Epoch 989/1000
# 5/5 [==============================] - 1s 105ms/step - d_loss: -0.5039 - g_loss: 0.3159
# Epoch 990/1000
# 5/5 [==============================] - 1s 108ms/step - d_loss: -0.5771 - g_loss: 0.1697
# Epoch 991/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3857 - g_loss: -0.0012
# Epoch 992/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.3270 - g_loss: 0.1061
# Epoch 993/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.3885 - g_loss: 0.1366
# Epoch 994/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.4685 - g_loss: 0.0642
# Epoch 995/1000
# 5/5 [==============================] - 0s 100ms/step - d_loss: -0.3676 - g_loss: 0.0102
# Epoch 996/1000
# 5/5 [==============================] - 0s 96ms/step - d_loss: -0.3100 - g_loss: -0.0603
# Epoch 997/1000
# 5/5 [==============================] - 1s 102ms/step - d_loss: -0.3768 - g_loss: -0.0811
# Epoch 998/1000
# 5/5 [==============================] - 1s 105ms/step - d_loss: -0.3621 - g_loss: -0.0775
# Epoch 999/1000
# 5/5 [==============================] - 1s 103ms/step - d_loss: -0.2907 - g_loss: -0.0734
# Epoch 1000/1000
# 5/5 [==============================] - 0s 102ms/step - d_loss: -0.2843 - g_loss: -0.0499

# %%
synth_data = []
for i in range(1000):
    x = generator2(generator1(tf.random.normal(shape=(1, noise_dim)), training=False),training=False)
    x = x.numpy()
    x = (x+1)*(max_crosssection[0]-min_crosssection[0])/2 + min_crosssection[0]
    synth_data.append(x[0,:,0,0])
    plt.plot(x[0,:,0,0])

# %%
from sklearn.decomposition import PCA

synth_data = np.array(synth_data)
synth_data.shape

elastic_data = (crosssection_data[:,0,:]+1)*(max_crosssection[0][0]-min_crosssection[0][0])/2 + min_crosssection[0][0]
elastic_crosssection = np.log(elastic_crosssection + 10**-25)

pca = PCA(n_components=2)
pca_results = pca.fit_transform(elastic_data)
pca_hat_results = pca.fit_transform(synth_data[:1000])
f, ax = plt.subplots(1)    
plt.scatter(pca_results[:,0], pca_results[:,1], alpha = 0.2, label = "Original")
plt.scatter(pca_hat_results[:,0], pca_hat_results[:,1], alpha = 0.2, label = "Synthetic")
ax.legend()  
plt.title('PCA plot')
plt.xlabel('x-pca')
plt.ylabel('y_pca')
plt.show()
